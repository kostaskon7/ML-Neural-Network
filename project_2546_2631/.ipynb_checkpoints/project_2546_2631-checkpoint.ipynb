# %% [markdown]
# #                                 Project for neuro-fuzzy computing
#
#
# ##                         Konstantinos Konstntinidis 2546 Stavrinos Nikolaos 2631
#
# Για τη παρουσίαση του project μας επιλέξαμε να τρέξουμε τον κώδικα τοπικά στο jupiter notebook σε environment του tensorflow για cpu έτσι ώστε να μπορέσουμε να περιγράψουμε κάθε κομμάτι του κώδικα ξεχωριστά.

# %% [markdown]
# ## Επιλέγουμε να κάνουμε train το μοντέλο μας με χρηση της τιμής close από τη κατανομή

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# Importing the Keras libraries and packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras import optimizers

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error


# Importing the training set
dataset_train = pd.read_excel('Stock_Price_Training_Data.xlsx')
training_set = dataset_train.iloc[:,1:2].values
print(training_set)

train_data = training_set[0:(len(training_set)-30), :]
valid_data = training_set[(len(training_set)-30):, :]
# Out:
# [[325.25]
#  [331.27]
#  [329.83]
#  ...
#  [793.7 ]
#  [783.33]
#  [782.75]]

# %% [markdown]
# ## Χρησιμοποιυμε scaling των τιμων απο -1 εως 1
# καθως με μεγαλες τιμες το training γινεται ασταθες που σημαίνει ότι μπορεί να υποφέρει από κακή απόδοση κατά τη διάρκεια της μάθησης, με αποτέλεσμα υψηλότερο generalization error.

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (-1, 1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
#  ## Για το project χωριζουμε το dataset σε training και testing
#  Το testing αποτελειται απο τις τελευταιες 30 τιμες του dataset.
#
# # Τα δεδομενα μας θα βασιζονται σε προβλεψη 60 timesteps και 1 output
#  βάση των προηγούμενων 60 ημερών πρόκειται να προβλέψουμε την τιμή της μετοχής στην 61η μέρα και θα γίνει για όλες τις τιμές του training set -60 μέρες

# %%
X_train = []
y_train = []
for i in range(60, len(train_data)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# ## Τα δεδομενα που θα χρησιμοποιηθουν για το validation των 30 τελευταιων τιμων

# %%
model_set = dataset_train.iloc[:, 1:2].values
model_data = model_set[(len(model_set)-len(valid_data)-60):, :]
model_data = model_data.reshape(-1, 1)
model_data_scaled = sc.transform(model_data)

X_test = []
y_test = []
for i in range(60, model_data_scaled.shape[0]):
    X_test.append(model_data_scaled[i-60:i, 0])
    y_test.append(model_data_scaled[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

# %% [markdown]
# ## Reshaping
# τα Frameworks όπως Keras / TensorFlow / PyTorch απαιτούν το σύνολο δεδομένων να γίνει reshaped σε άλλη διάσταση που την καθορίζει η δεύτερη του παράμετρος https://www.tensorflow.org/api_docs/python/tf/reshape

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# # Building the reccurent neural network for our prediction

# %% [markdown]
# ## Initialising the RNN
#
# Επιλεξαμε την LSTM καθως μπορει να απομνημονεύσει πληροφορίες για μεγάλα χρονικά διαστήματα, και ειναι χρησιμη για μεγαλα input
# files με training data,οπως στη δικια μας περιπτωση.
#
# ## Χρησιμοποιόυμε 4 layers της LSTM
# Το 1ο και 4ο layer εχουν απο 50 νευρωνες,ενω 2ο και 3ο απο 100 με 1 τελικη εξοδο.Επιση το 1ο layer χρησιμοποιει ως συναρτηση ενεργοποιησης την sigmoid.
# Δεν χρησιμοποιησαμε dropout επειδη το LSTM ειναι καλο για long-term υπολογισμους και δεν θελαμε να υπαρχει περιπτωση να χασουμε σημαντικα δεδομενα λογω του dropout.

# %%
regressor = Sequential()

regressor.add(LSTM(units=50, return_sequences=True, input_shape=(
    X_train.shape[1], 1), activation='sigmoid', bias_initializer='glorot_uniform'))

regressor.add(LSTM(units=100,  return_sequences=True,
                   bias_initializer='glorot_uniform'))

regressor.add(LSTM(units=100,  return_sequences=True,
                   bias_initializer='glorot_uniform'))

regressor.add(LSTM(units=50, bias_initializer='glorot_uniform'))

regressor.add(Dense(units=1))

# %% [markdown]
# ## Weight and bias values before training

# %%
for layer in regressor.layers:
  print(layer)
  print("Weights :")
  print(layer.get_weights()[0])
  print("Biases:")
  print(layer.get_weights()[1])
# Out:
# <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x0000011D389FFB50>
# Weights :
# [[-0.14669837  0.0460331   0.02727716  0.00272225 -0.02405681 -0.04153275
#   -0.11330476 -0.10146349 -0.11121918  0.0831686   0.06838368 -0.05204844
#   -0.09384754  0.04313971 -0.1368551   0.13697904  0.14850852 -0.14266838
#   -0.14634939  0.08461308  0.11153829 -0.12915236 -0.07150525 -0.11999594
#   -0.13065559 -0.07490519  0.15232313  0.02401105  0.08250195 -0.10027748
#   -0.12066466  0.17080313  0.1523008  -0.06956623 -0.06958593  0.01379997
#   -0.16459851 -0.08000135  0.16368392 -0.11535865  0.02694972 -0.05826665
#   -0.15581954  0.01253878 -0.05790585  0.12678596  0.12072372  0.07461202
#   -0.04609779 -0.14460982  0.11607143 -0.11822166 -0.09283911 -0.11508913
#    0.08370069 -0.0541617  -0.07243138  0.07142521  0.1649589   0.03752027
#    0.04306564  0.03479387 -0.10855988 -0.1726362  -0.13300262 -0.08265193
#   -0.07309103  0.03128192 -0.14317472  0.13108462 -0.14861336  0.15049875
#    0.1605084   0.08349368 -0.05369709  0.05166033 -0.03269432  0.04736358
#   -0.02094224  0.02907455 -0.15773408  0.14368331  0.08452207  0.06015195
#   -0.04700191  0.01149558 -0.15015289  0.06213363 -0.00836219 -0.00204274
#    0.16949502 -0.06394874 -0.12699132 -0.07459596 -0.04186904 -0.05321806
#   -0.07656537 -0.12445839  0.04244582  0.13423634  0.04257549 -0.13431436
#   -0.10444389 -0.1068653   0.10801017 -0.16792007 -0.03338678  0.01497374
#    0.1430287  -0.11943617  0.12769645  0.10313377  0.1676552  -0.0767123
#   -0.16819507 -0.0192882   0.05528089  0.05810612  0.07590233  0.05339308
#   -0.03845361 -0.13466568 -0.14833269 -0.08248917 -0.1669513   0.046803
#    0.08551079 -0.07264228 -0.07040932  0.1411598   0.0604838   0.06125779
#    0.05078457 -0.12118112 -0.02031949 -0.15742476 -0.03173804 -0.04350677
#    0.06817904 -0.14293131 -0.00226463 -0.06417406 -0.06579223  0.05306914
#    0.04501294 -0.15203683  0.00630583  0.03548425  0.12374836  0.09561679
#   -0.04447559 -0.14661948 -0.09586816  0.02303889  0.02600558  0.07439646
#   -0.09615568  0.0238768   0.12094414 -0.10378505 -0.03416799 -0.14781266
#    0.08578197]]
# Biases:
# [[ 0.03318298  0.05288591  0.11189004 ... -0.01372124 -0.08796509
#    0.05585589]
#  [ 0.05127953 -0.07205379 -0.07610826 ... -0.01842248 -0.02335534
#   -0.01516538]
#  [-0.00878584 -0.04441702 -0.00226623 ...  0.01275316 -0.02904918
#   -0.06663606]
#  ...
#  [ 0.03272956 -0.00688406  0.04822987 ...  0.12437465 -0.04168647
#   -0.07872251]
#  [ 0.07350043  0.07575409 -0.0155046  ...  0.06286287 -0.03955258
#    0.02417538]
#  [ 0.01932638  0.06586943  0.06468302 ...  0.01926954  0.02858402
#    0.0063854 ]]
# <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x0000011D43B92910>
# Weights :
# [[-0.09332196  0.03865628  0.02198316 ... -0.04582269 -0.10712273
#    0.06411234]
#  [-0.04724773  0.07308146  0.11723672 ... -0.0566313  -0.02142651
#    0.0233437 ]
#  [ 0.01334201  0.04946779 -0.0026571  ... -0.05550413 -0.11956164
#    0.08668318]
#  ...
#  [ 0.05284116  0.00568116 -0.03743945 ... -0.03648457 -0.0823361
#   -0.11881484]
#  [-0.1254535   0.06681466  0.09065568 ...  0.09757842  0.06423476
#    0.08772857]
#  [-0.12892674 -0.09693631  0.01018183 ... -0.03057083 -0.04606074
#   -0.09798236]]
# Biases:
# [[-0.16612434  0.0167594  -0.02678176 ...  0.03399983  0.04142348
#   -0.00810205]
#  [ 0.03651477  0.08269429  0.1071365  ...  0.01485937  0.09798381
#    0.00509609]
#  [ 0.05398478 -0.10755708  0.04476714 ... -0.00335471  0.0425598
#   -0.0590486 ]
#  ...
#  [ 0.05775692  0.05059054 -0.00182992 ... -0.02175688  0.0305365
#   -0.04107151]
#  [ 0.03582091  0.01659292  0.00601005 ... -0.10758011 -0.00214876
#   -0.0219087 ]
#  [-0.04153966 -0.07107695  0.01394285 ... -0.02845693 -0.04004398
#    0.07346627]]
# <tensorflow.python.keras.layers.core.Dense object at 0x0000011D44E86DC0>
# Weights :
# [[-0.15094559]
#  [-0.17519702]
#  [ 0.33343396]
#  [ 0.14786392]
#  [-0.18948574]
#  [-0.2584992 ]
#  [-0.33720964]
#  [ 0.21764389]
#  [-0.31339556]
#  [ 0.08478916]
#  [ 0.16868642]
#  [ 0.33341333]
#  [-0.25145194]
#  [ 0.0046258 ]
#  [ 0.33308324]
#  [-0.3416979 ]
#  [-0.12145005]
#  [-0.18969451]
#  [-0.26038224]
#  [-0.17286344]
#  [ 0.19200996]
#  [-0.15073453]
#  [ 0.32800558]
#  [-0.31434703]
#  [ 0.33170417]
#  [-0.16553721]
#  [-0.2216122 ]
#  [ 0.21494648]
#  [-0.19931434]
#  [-0.3072174 ]
#  [ 0.19022289]
#  [ 0.05976075]
#  [ 0.06178254]
#  [ 0.32657728]
#  [ 0.09819812]
#  [-0.26958466]
#  [ 0.04366657]
#  [-0.2512278 ]
#  [-0.08595684]
#  [-0.33354834]
#  [ 0.20744029]
#  [ 0.12151811]
#  [ 0.21648005]
#  [ 0.21501997]
#  [ 0.13400632]
#  [-0.02023798]
#  [-0.12440751]
#  [ 0.19053093]
#  [ 0.21084777]
#  [ 0.13068545]]
# Biases:
# [0.]

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 100)           60400
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 100)           80400
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 181,451
# Trainable params: 181,451
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Setting the optimizer
# ## Χρησιμοποιούμε τον [adam](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam) με τις βασικές παραμέτρους του όπως χρησιμοποιόυνται και στο site του tensorflow
# Ο Adam είναι ένας αλγόριθμος βελτιστοποίησης που μπορεί να χρησιμοποιηθεί αντί της διαδικασίας της κλασικής stochastic gradient descent για την ενημέρωση επαναληπτικών βαρών δικτύου με βάση τα δεδομένα εκπαίδευσης.

# %%
optimizer = optimizers.Adam(lr=0.001 , beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

# %% [markdown]
# ## Loss function
# Ορίζουμε ως loss function μας την [mean_squared_error](https://keras.io/api/losses/regression_losses/#mean_squared_error-function)

# %%
regressor.compile(optimizer = optimizer, loss = 'mean_squared_error')

# %% [markdown]
# ## Start the training
# Επιλεγουμε batch size=32 και epochs=100 μετα απο αρκετες δοκιμες

# %%
start=time.time()
# Fitting the RNN to the Training set
history = regressor.fit(X_train, y_train, epochs=100,
                        batch_size=32, validation_data=(X_test, y_test))
end=time.time()
# Out:
# Epoch 1/100
# 37/37 [==============================] - 6s 154ms/step - loss: 0.2759 - val_loss: 0.2441
# Epoch 2/100
# 37/37 [==============================] - 4s 107ms/step - loss: 0.0444 - val_loss: 0.0257
# Epoch 3/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0125 - val_loss: 0.0072
# Epoch 4/100
# 37/37 [==============================] - 4s 106ms/step - loss: 0.0113 - val_loss: 0.0042
# Epoch 5/100
# 37/37 [==============================] - 4s 105ms/step - loss: 0.0103 - val_loss: 0.0047
# Epoch 6/100
# 37/37 [==============================] - 4s 112ms/step - loss: 0.0097 - val_loss: 0.0040
# Epoch 7/100
# 37/37 [==============================] - 4s 111ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 8/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.0094 - val_loss: 0.0055
# Epoch 9/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0085 - val_loss: 0.0058
# Epoch 10/100
# 37/37 [==============================] - 4s 107ms/step - loss: 0.0071 - val_loss: 0.0173
# Epoch 11/100
# 37/37 [==============================] - 4s 104ms/step - loss: 0.0084 - val_loss: 0.0033
# Epoch 12/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 13/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.0076 - val_loss: 0.0031
# Epoch 14/100
# 37/37 [==============================] - 4s 111ms/step - loss: 0.0058 - val_loss: 0.0033
# Epoch 15/100
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 16/100
# 37/37 [==============================] - 4s 109ms/step - loss: 0.0060 - val_loss: 0.0062
# Epoch 17/100
# 37/37 [==============================] - 4s 106ms/step - loss: 0.0055 - val_loss: 0.0069
# Epoch 18/100
# 37/37 [==============================] - 4s 112ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 19/100
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch
ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 79/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 80/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0018 - val_loss: 8.2039e-04
# Epoch 81/100
# 37/37 [==============================] - 4s 106ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 82/100
# 37/37 [==============================] - 4s 114ms/step - loss: 0.0013 - val_loss: 9.6524e-04
# Epoch 83/100
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0014 - val_loss: 8.7094e-04
# Epoch 84/100
# 37/37 [==============================] - 4s 110ms/step - loss: 0.0013 - val_loss: 8.2078e-04
# Epoch 85/100
# 37/37 [==============================] - 4s 110ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 86/100
# 37/37 [==============================] - 4s 106ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 87/100
# 37/37 [==============================] - 4s 101ms/step - loss: 0.0012 - val_loss: 7.9225e-04
# Epoch 88/100
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 89/100
# 37/37 [==============================] - 4s 106ms/step - loss: 0.0015 - val_loss: 7.7584e-04
# Epoch 90/100
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0013 - val_loss: 7.4765e-04
# Epoch 91/100
# 37/37 [==============================] - 4s 101ms/step - loss: 0.0015 - val_loss: 8.0934e-04
# Epoch 92/100
# 37/37 [==============================] - 4s 101ms/step - loss: 0.0018 - val_loss: 8.7593e-04
# Epoch 93/100
# 37/37 [==============================] - 4s 104ms/step - loss: 0.0014 - val_loss: 8.5270e-04
# Epoch 94/100
# 37/37 [==============================] - 4s 101ms/step - loss: 0.0015 - val_loss: 9.8138e-04
# Epoch 95/100
# 37/37 [==============================] - 4s 101ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 96/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 97/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0014 - val_loss: 8.5685e-04
# Epoch 98/100
# 37/37 [==============================] - 4s 105ms/step - loss: 0.0013 - val_loss: 7.7490e-04
# Epoch 99/100
# 37/37 [==============================] - 4s 100ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 100/100
# 37/37 [==============================] - 4s 102ms/step - loss: 0.0015 - val_loss: 9.8626e-04

# %%
print("It took '{}' seconds to to train the model".format(np.round(end-start,4)))
# Out:
# It took '409.9539' seconds to to train the model

# %% [markdown]
# ## Weight and bias values after training

# %%
for layer in regressor.layers:
  print(layer)
  print("Weights :")
  print(layer.get_weights()[0])
  print("Biases:")
  print(layer.get_weights()[1])
# Out:
# <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x0000011D389FFB50>
# Weights :
# [[-0.02792976 -0.12109425 -0.14425746 -0.13068807  0.12121221 -0.22131482
#   -0.2744932  -0.02616438  0.0570289   0.02458808 -0.04085095 -0.20649785
#   -0.03496416 -0.12368718 -0.08487827  0.00202089 -0.00669298 -0.26210326
#   -0.30780885  0.2624909   0.29501495 -0.03998406  0.07612833 -0.15385616
#    0.06983611 -0.23690258  0.30987787 -0.11850107  0.22739923  0.07399669
#   -0.25502542  0.3402148   0.01778484 -0.1526861  -0.21949403  0.16783197
#    0.01155246 -0.21277937 -0.00169016 -0.2643567   0.19434465 -0.22073907
#   -0.30899033  0.16707346  0.09786426  0.2934661   0.03524343 -0.09531289
#    0.14843456  0.02270909  0.23117423 -0.29200575 -0.2695841  -0.24668346
#    0.23124115 -0.2177199  -0.23167445  0.14172502  0.3363432  -0.01584709
#   -0.06337976 -0.12097842 -0.05327559 -0.33956888 -0.08667221 -0.21840392
#   -0.08806517]
#  [-0.12111893  0.11324937 -0.02875473 ... -0.05586259  0.08632079
#    0.03943887]
#  [-0.0118838   0.07374237 -0.05907891 ...  0.11908273  0.10261642
#   -0.01537014]]
# Biases:
# [[ 0.03907846  0.10197208 -0.05457197 ...  0.10109313  0.0688381
#    0.14134198]
#  [ 0.03519466  0.08978093 -0.06037422 ... -0.12558255  0.01402052
#   -0.00266804]
#  [-0.0235502   0.04254818 -0.01812304 ...  0.07718439 -0.00925229
#    0.04118629]
#  ...
#  [ 0.0320375   0.08542424  0.05371092 ...  0.05184973 -0.04542487
#   -0.04047865]
#  [ 0.01743663 -0.06839305  0.04459117 ... -0.03811471  0.02644283
#   -0.00479223]
#  [ 0.00173836 -0.05162058 -0.03287486 ... -0.04510639  0.03558641
#    0.03495455]]
# <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x0000011D43B0F5E0>
# Weights :
# [[-0.00670507  0.09056381 -0.07808878 ...  0.01325926  0.10352601
#   -0.05079765]
#  [ 0.08321159  0.03982341 -0.03523826 ...  0.15349397  0.00963781
#   -0.07563423]
#  [ 0.05540884 -0.0587175   0.01985087 ... -0.04889154 -0.03770672
#   -0.041309  ]
#  ...
#  [-0.02608696  0.04500474  0.03923515 ...  0.02486382 -0.01924866
#    0.01035004]
#  [ 0.00544416  0.04853402  0.02029414 ... -0.07077858  0.03182415
#   -0.05185603]
#  [ 0.02866553 -0.07757472 -0.04527455 ...  0.12553044 -0.08076832
#    0.07660156]]
# Biases:
# [[ 0.03204465  0.05355429  0.11114869 ... -0.00741983 -0.08479819
#    0.05393432]
#  [ 0.04336678 -0.06495313 -0.11778402 ... -0.02537036 -0.04934485
#   -0.02026767]
#  [-0.01200781 -0.03395901 -0.00772335 ...  0.01535846 -0.03192604
#   -0.07147616]
#  ...
#  [ 0.03212221  0.0226084   0.02115119 ...  0.11765423 -0.06770273
#   -0.08463212]
#  [ 0.07174404  0.08992369  0.01690649 ...  0.06764705 -0.02934738
#    0.0223856 ]
#  [ 0.01667718  0.06467819  0.06337402 ...  0.01996481  0.02643007
#    0.00349825]]
# <tensorflow.python.keras.layers.recurrent_v2.LSTM object at 0x0000011D43B92910>
# Weights :
# [[-0.11438597  0.04469894  0.02183913 ... -0.05821624 -0.1193059
#    0.07043306]
#  [-0.07312358  0.05516335  0.09576195 ... -0.0657129  -0.16601513
#    0.03259975]
#  [-0.03250399  0.0628358  -0.00487973 ... -0.08585302 -0.18509465
#    0.10890396]
#  ...
#  [ 0.00255197 -0.00233249 -0.03907756 ... -0.0710123  -0.23787083
#   -0.07947185]
#  [-0.15393114  0.09046756  0.10967061 ...  0.05670203  0.03784429
#    0.1339406 ]
#  [-0.13911939 -0.09551014  0.00383378 ... -0.03761216 -0.05904573
#   -0.0958645 ]]
# Biases:
# [[-0.18046753 -0.03009733 -0.0441498  ...  0.03550684 -0.04839611
#   -0.01380255]
#  [ 0.07483309  0.0810625   0.11025234 ...  0.0267127   0.30824897
#   -0.01448747]
#  [ 0.06786714 -0.10084503  0.0449329  ... -0.00436361  0.03552659
#   -0.04660634]
#  ...
#  [ 0.06734135  0.07333879  0.00755114 ... -0.02002348  0.08649001
#   -0.04185062]
#  [ 0.02974886  0.04764265  0.01417181 ... -0.10434174  0.00608165
#   -0.00805632]
#  [-0.06911133 -0.08493211  0.0020277  ... -0.04058316 -0.16768241
#    0.08696873]]
# <tensorflow.python.keras.layers.core.Dense object at 0x0000011D44E86DC0>
# Weights :
# [[-0.15405707]
#  [-0.18095113]
#  [ 0.3417114 ]
#  [ 0.1699564 ]
#  [-0.18918115]
#  [-0.2605287 ]
#  [-0.38362676]
#  [ 0.293689  ]
#  [-0.35237613]
#  [ 0.08303558]
#  [ 0.21580775]
#  [ 0.3406577 ]
#  [-0.24810605]
#  [-0.00850385]
#  [ 0.347423  ]
#  [-0.33346394]
#  [-0.11736792]
#  [-0.18208407]
#  [-0.25085646]
#  [-0.17076069]
#  [ 0.18741715]
#  [-0.16134658]
#  [ 0.3269593 ]
#  [-0.3147929 ]
#  [ 0.32123035]
#  [-0.16357617]
#  [-0.22209571]
#  [ 0.20086664]
#  [-0.19571656]
#  [-0.3183112 ]
#  [ 0.18242343]
#  [ 0.05817582]
#  [ 0.0569715 ]
#  [ 0.3319038 ]
#  [ 0.10529641]
#  [-0.28271216]
#  [ 0.03550348]
#  [-0.24094911]
#  [-0.085119  ]
#  [-0.33260003]
#  [ 0.20023082]
#  [ 0.1334061 ]
#  [ 0.2399386 ]
#  [ 0.21449353]
#  [ 0.14922582]
#  [-0.04621068]
#  [-0.11203568]
#  [ 0.19612378]
#  [ 0.25088084]
#  [ 0.12487717]]
# Biases:
# [0.00076732]

# %% [markdown]
# ## Εκτύπωση του loss του μοντελου μας

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# ## Αποτιμηση της επιδοση πανω στα δεδομενα

# %%
print("\n\n EVALUATION")
start = time.time()
score = regressor.evaluate(X_test, y_test, batch_size=1)
end = time.time()
print("This test uses the validation set and Testing time took '{}' seconds".format(
    np.round(end - start, 4)))

print("\n", regressor.metrics_names,
      "on the validation dataset is " + str(score))
# Out:
#  EVALUATION
# 30/30 [==============================] - 0s 10ms/step - loss: 9.8626e-04
# This test uses the validation set and Testing time took '1.7194' seconds
#
#  ['loss'] on the validation dataset is 0.0009862574515864253

# %% [markdown]
# ## Χρονος αποκρισης υπολογισμου prediction

# %%
print("\n\n Network response time")
start = time.time()
predicted_stock_price = regressor.predict(X_test)
end = time.time()

predicted_stock_price = sc.inverse_transform(predicted_stock_price)

print("This test took '{}' seconds".format(np.round(end - start, 4)))
# Out:
#  Network response time
# This test took '1.8002' seconds

# %% [markdown]
# ## Ο πραγματικος ελεγχος θα γινει απο τον εξεταστη, για τη παρουσιαση ωστοσο κανουμε validation με τα 30 τελευταια στοιχεια του training set

# %%
plt.plot(valid_data, color='blue', label='Stock Price')
plt.plot(predicted_stock_price, color='green', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Printing the absolute error

# %%
print("\n The mean absolute error is  ", mean_absolute_error(
    valid_data, predicted_stock_price))
# Out:
#  The mean absolute error is   7.210379475911452
